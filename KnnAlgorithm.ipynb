# %%
import pandas as pd
from sklearn.preprocessing import LabelEncoder 
df = pd.read_csv("assets/Cars93.csv")
le = LabelEncoder()
df2 = df.apply(le.fit_transform)
df2.head()
# Out:
#    Unnamed: 0  Manufacturer  Model  Type  Min.Price  Price  Max.Price  \
# 0           0             0     48     3         25     33         36
# 1           1             0     55     2         67     71         73
# 2           2             1      8     0         63     66         63
# 3           3             1      0     2         69     76         76
# 4           4             2      5     2         61     68         69
#
#    MPG.city  MPG.highway  AirBags  ...  Passengers  Length  Wheelbase  Width  \
# 0        10           11        2  ...           2      18         10      6
# 1         3            5        0  ...           2      36         23      9
# 2         5            6        1  ...           2      21         10      5
# 3         4            6        0  ...           3      34         14      8
# 4         7           10        1  ...           1      27         17      7
#
#    Turn.circle  Rear.seat.room  Luggage.room  Weight  Origin  Make
# ...

# %%
X = df2[["Price","MPG.city","MPG.highway","Passengers","Length"]]
Y = df2[["AirBags"]]
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.neighbors import KNeighborsClassifier
xtrain, xtest, ytrain, ytest = train_test_split(X, Y, test_size = 0.3, random_state = 21)
knn = KNeighborsClassifier()
params = { "n_neighbors" : range(2,30,1)}
cv = GridSearchCV(knn,params,scoring="accuracy",cv=4)

# %%
cvmodel = cv.fit(xtrain,ytrain)
cv.best_params_
# Out:
# /Users/prathameshmadur/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:528: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /Users/prathameshmadur/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:528: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /Users/prathameshmadur/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:528: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# ...

# %%
knn = KNeighborsClassifier(n_neighbors=10)
model = knn.fit(xtrain,ytrain)
pred = model.predict(xtest)
# Out:
# /Users/prathameshmadur/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().

# %%
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(ytest,pred)

# %%
cm
# Out:
# array([[0, 7, 2],
#        [0, 9, 5],
#        [0, 1, 4]])
