# %%
import pandas as pd
from sklearn.preprocessing import LabelEncoder
df = pd.read_csv("assets/Cars93.csv")
le = LabelEncoder()
df2 = df.apply(le.fit_transform)
df2.head()
# Out:
#    Unnamed: 0  Manufacturer  Model  Type  Min.Price  Price  Max.Price  \
# 0           0             0     48     3         25     33         36
# 1           1             0     55     2         67     71         73
# 2           2             1      8     0         63     66         63
# 3           3             1      0     2         69     76         76
# 4           4             2      5     2         61     68         69
#
#    MPG.city  MPG.highway  AirBags  ...  Passengers  Length  Wheelbase  Width  \
# 0        10           11        2  ...           2      18         10      6
# 1         3            5        0  ...           2      36         23      9
# 2         5            6        1  ...           2      21         10      5
# 3         4            6        0  ...           3      34         14      8
# 4         7           10        1  ...           1      27         17      7
#
#    Turn.circle  Rear.seat.room  Luggage.room  Weight  Origin  Make
# ...

# %%
X = df2[["MPG.highway","Price"]]
from sklearn.cluster import KMeans
km = KMeans(n_clusters=4)
model = km.fit(X)
df2["clustering_vector"] = model.labels_

# %%
from sklearn.cluster import KMeans
WCSS = []
KValue = range(2,20,1)

for k in range(2,20,1):
    km = KMeans(n_clusters=k)
    model = km.fit(X)
    WCSS.append(model.inertia_)

# %%
import matplotlib.pyplot as plt
plt.plot(KValue,WCSS,'bx-',c="red")
plt.xlabel("K number of clusters")
plt.ylabel("Within cluster sum of squares")
plt.xticks(range(1,20,1))
plt.title("ELBOW CURVE")
# Out:
# Text(0.5, 1.0, 'ELBOW CURVE')

# %%
X = df2[["MPG.highway","Price"]]
from sklearn.cluster import KMeans
km = KMeans(n_clusters=4)
model = km.fit(X)
df2["clustering_vector"] = model.labels_

# %%
colors = {0: "red", 1: "blue", 2: "green", 3: "yellow"}
coloring = []
for vector in df2.clustering_vector:
    coloring.append(colors[vector])

# %%
import matplotlib.pyplot as plt2
plt2.scatter(df2.Price,df2['MPG.highway'],c=coloring)

# %%
df2
# Out:
#     Unnamed: 0  Manufacturer  Model  Type  Min.Price  Price  Max.Price  \
# 0            0             0     48     3         25     33         36
# 1            1             0     55     2         67     71         73
# 2            2             1      8     0         63     66         63
# 3            3             1      0     2         69     76         76
# 4            4             2      5     2         61     68         69
# 5            5             3     23     2         32     31         29
# 6            6             3     53     1         53     53         44
# 7            7             3     73     1         59     58         54
# 8            8             3     72     2         64     62         56
# 9            9             4     34     1         71     73         70
# 10          10             4     78     2         76     78         75
# 11          11             5     21     0         10     22         32
# ...
